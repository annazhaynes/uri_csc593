# %% [markdown]
# # CSC 593

# %% [markdown]
# ## Week 5

# %% [markdown]
# ### Reading and Writing Files

# %% [markdown]
# The built-in function [`open()`](https://docs.python.org/3/library/functions.html#open) returns a "file object" that can be used to read from and/or write to a file.
#
# In general we do file input/output inside code blocks started with the `with` keyword. This just simplifies the process of managing the file object and closing it after you've finished.
#
# `open()` takes two arguments: a path to the file on the filesystem, and the *mode* we want to open the file in. To read from the file, use 'r' as the mode. Use the file object's `read()` method to read the entire file, or `readline()` to read one line at a time.

# %%
with open('../data/textfile.txt', 'r') as f:
    print(f.read())
# Out:
# This is just a short text file.
#
# Here is another line of text.

# %% [markdown]
# Use mode 'w' to write to the file:

# %%
with open('../data/newfile.txt', 'w') as f:
    f.write("""This is some text.
    
This is some more text.""")

# %%
with open('../data/newfile.txt', 'r') as f:
    print(f.readline())
# Out:
# This is some text.

# %% [markdown]
# You can also iterate over the file object, line by line:

# %%
with open('../data/newfile.txt', 'r') as f:
    for ln in f:
        print(ln, end=' ')
# Out:
# This is some text.
#
#  This is some more text.

# %% [markdown]
# Be careful: `open(filename, 'w')` will overwrite existing files.

# %%
open('../data/newfile.txt', 'w').close()  # our new file is now empty.

with open('../data/newfile.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# Using mode 'x' will open a new file for writing, but throw an error if the file already exists.

# %%
with open('../data/textfile.txt', 'x') as f:
    pass
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-214-07ae712a1ce3> in <module>
# ----> 1 with open('../data/textfile.txt', 'x') as f:
#       2     pass
#
# FileExistsError: [Errno 17] File exists: '../data/textfile.txt'

# %% [markdown]
# #### Practice
#
# Try opening the class syllabus ('../README.md') and printing the first line.

# %%
with open('..//README.md', 'r') as f:
   print(f.readline())
# Out:
# # University of Rhode Island

# %% [markdown]
# ##### `CSV`
#
# Comma-separated values files are a common data exchange format. Python has built-in support for them:

# %%
import csv

# %% [markdown]
# To read a CSV file, open it like any other, then read the file object with a `csv.reader()`. Here we use the `next()` function to retrieve the first line of the `familyxx.csv` file, then print the header labels.
#
# `familyxx.csv` is part of the data release from the 2018 [National Health Interview Survey](https://www.cdc.gov/nchs/nhis/index.htm).

# %%
with open('../dataset/crime/crime.csv') as f:
    rdr = csv.reader(f)
    #feed to csv reader
    hdr = next(rdr)
    for name in hdr:
        print(name)
# Out:
# INCIDENT_NUMBER
# OFFENSE_CODE
# OFFENSE_CODE_GROUP
# OFFENSE_DESCRIPTION
# DISTRICT
# REPORTING_AREA
# SHOOTING
# OCCURRED_ON_DATE
# YEAR
# MONTH
# DAY_OF_WEEK
# HOUR
# UCR_PART
# STREET
# Lat
# Long
# Location

# %% [markdown]
# ##### `zip()`
#
# The [`zip`](https://docs.python.org/3/library/functions.html#zip) function merges two or more iterables (like lists or strings).

# %%
l1 = [1, 2, 3]
l2 = ['a', 'b', 'c']
l3 = ['x', 'y', 'z']
for x in zip(l1, l2, l3):
    print(x)

for x in zip('foo', 'bar'):
    print(x)
# Out:
# (1, 'a', 'x')
# (2, 'b', 'y')
# (3, 'c', 'z')
# ('f', 'b')
# ('o', 'a')
# ('o', 'r')

# %% [markdown]
# This gives us another way to answer the last question from homework assignment 2:

# %%
string1 = 'ABCDEFGHIJ'
string2 = 'ABCDEEGHIJ'

for x in zip(string1, string2):
    print(*x, sep='')
# Out:
# AA
# BB
# CC
# DD
# EE
# FE
# GG
# HH
# II
# JJ

# %% [markdown]
# More importantly, it's a convenient way to create dictionaries from two lists:

# %%
dict(zip(l2, l1))
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# Here, we create a list of dictionaries, each containing one row of the `familyxx` data.

# %%
with open('../data/nhis/familyxx.csv') as f:
    rdr = csv.reader(f)
    hdr = next(rdr)
    #saves first line as the header
    nhis = [dict(zip(hdr, row)) for row in rdr]
    #make dictionary with header values as keys and the data in each row as dictionary values
    #equivalent to:
    #nhis=[]
    #for row in rdr:
        #nhis.append(dict(zip(hdr,row)))

# %%
print(len(nhis))
print(nhis[0])
# Out:
# 30309
# {'FINT_Y_P': '2018', 'FINT_M_P': '1', 'FMX': '01', 'RECTYPE': '60', 'SRVY_YR': '2018', 'HHX': '000001', 'FM_SIZE': '1', 'FM_STRCP': '11', 'FM_TYPE': '1', 'FM_STRP': '11', 'TELN_FLG': '1', 'CURWRKN': '1', 'TELCELN': '1', 'WRKCELN': '1', 'PHONEUSE': '3', 'FLNGINTV': '1', 'WTFA_FAM': '3539', 'FM_KIDS': '0', 'FM_ELDR': '1', 'FM_EDUC1': '2', 'F10DVCT': '0', 'F10DVYN': '2', 'FDMEDCT': '0', 'FDMEDYN': '2', 'FHCDVCT': '1', 'FHCDVYN': '1', 'FHCHMCT': '0', 'FHCHMYN': '2', 'FHCPHRCT': '1', 'FHCPHRYN': '1', 'FHOSP2CT': '0', 'FHOSP2YN': '2', 'FNMEDCT': '0', 'FNMEDYN': '2', 'FSRUNOUT': '3', 'FSLAST': '3', 'FSBALANC': '3', 'FSSKIP': '', 'FSSKDAYS': '', 'FSLESS': '', 'FSHUNGRY': '', 'FSWEIGHT': '', 'FSNOTEAT': '', 'FSNEDAYS': '', 'FHDSTCT': '', 'FDGLWCT1': '0', 'FDGLWCT2': '0', 'FWRKLWCT': '', 'FCHLMYN': '', 'FSPEDYN': '', 'FLAADLYN': '2', 'FLIADLYN': '2', 'FWKLIMYN': '2', 'FWALKYN': '2', 'FREMEMYN': '2', 'FANYLYN': '2', 'FCHLMCT': '', 'FSPEDCT': '', 'FLIADLCT': '0', 'FWKLIMCT': '0', 'FWALKCT': '0', 'FREMEMCT': '0', 'FANYLCT': '0', 'FHSTATEX': '0', 'FHSTATVG': '0', 'FHSTATG': '1', 'FHSTATFR': '0', 'FHSTATPR': '0', 'FLAADLCT': '0', 'FGAH': '', 'HOUSEOWN': '1', 'FSNAP': '2', 'FSNAPMYR': '', 'INCGRP4': '1', 'INCGRP5': '1', 'RAT_CAT4': '5', 'RAT_CAT5': '5', 'FSALYN': '2', 'FSEINCYN': '2', 'FSSRRYN': '1', 'FPENSYN': '2', 'FOPENSYN': '2', 'FSSIYN': '2', 'FTANFYN': '2', 'FOWBENYN': '2', 'FINTR1YN': '2', 'FDIVDYN': '2', 'FCHSPYN': '2', 'FINCOTYN': '2', 'FSSAPLYN': '2', 'FSDAPLYN': '2', 'FWICYN': '', 'FSALCT': '0', 'FSEINCCT': '0', 'FSSRRCT': '1', 'FPENSCT': '0', 'FOPENSCT': '0', 'FSSICT': '0', 'FTANFCT': '0', 'FOWBENCT': '0', 'FINTR1CT': '0', 'FDIVDCT': '0', 'FCHSPCT': '0', 'FINCOTCT': '0', 'FSSAPLCT': '0', 'FSDAPLCT': '0', 'FWICCT': '', 'FHIPRVCT': '0', 'FHISINCT': '0', 'FHICARCT': '1', 'FHICADCT': '0', 'FHICHPCT': '0', 'FHIMILCT': '0', 'FHIPUBCT': '0', 'FHIOGVCT': '0', 'FHIIHSCT': '0', 'FHIEXCT': '0', 'COVCONF': '', 'FHICOST': '1', 'FMEDBILL': '2', 'FMEDBPAY': '2', 'FMEDBNOP': '', 'FSAF': '2', 'FHICOVCT': '1', 'FHICOVYN': '1', 'FPRCOOH': '', 'FHIEBCCT': ''}

# %% [markdown]
# #### Practice
# Import your own dataset, or the NHIS persons file (`..\data\nhis\personsx.csv`). Create a list of dictionaries, as I have above.

# %%
with open('../dataset/crime/crime.csv') as f:
    rdr = csv.reader(f)
    hdr = next(rdr)
    crimes = [dict(zip(hdr, row)) for row in rdr]
    
print(len(crimes))
print(crimes[0])
# Out:
# 319073
# {'INCIDENT_NUMBER': 'I182070945', 'OFFENSE_CODE': '00619', 'OFFENSE_CODE_GROUP': 'Larceny', 'OFFENSE_DESCRIPTION': 'LARCENY ALL OTHERS', 'DISTRICT': 'D14', 'REPORTING_AREA': '808', 'SHOOTING': '', 'OCCURRED_ON_DATE': '2018-09-02 13:00:00', 'YEAR': '2018', 'MONTH': '9', 'DAY_OF_WEEK': 'Sunday', 'HOUR': '13', 'UCR_PART': 'Part One', 'STREET': 'LINCOLN ST', 'Lat': '42.35779134', 'Long': '-71.13937053', 'Location': '(42.35779134, -71.13937053)'}

# %% [markdown]
# ### Web Scraping

# %% [markdown]
# We'll use the [`requests`](https://3.python-requests.org/) module to retrieve data from the web, and [`Beautiful Soup`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) to read these pages.

# %%
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# Get [Wikipedia's list of Rhode Island municipalities](https://en.wikipedia.org/wiki/List_of_municipalities_in_Rhode_Island). A response code of 200 means "OK"

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_municipalities_in_Rhode_Island')
page
# Out:
# <Response [200]>

# %% [markdown]
# Parse the source of the page with BeautifulSoup and find the table. We know it has the class 'wikitable'. We have to do some tinkering here--the table is messier than the CDC's file.

# %%
#th = table.find_all('th')
#html text inside that table
print(th[2])
#gives just text
print(th[2].text)
#
print(th[2].text.strip())
#
print(th[2].text.strip().split('['))
#
print(th[2].text.strip().split('[')[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-1674a399083d> in <module>
#       1 #th = table.find_all('th')
#       2 #html text inside that table
# ----> 3 print(th[2])
#       4 #gives just text
#       5 print(th[2].text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1014         """tag[key] returns the value of the 'key' attribute for the tag,
#    1015         and throws an exception if it's not there."""
# -> 1016         return self.attrs[key]
#    1017
#    1018     def __iter__(self):
#
# KeyError: 2

# %%
#parsed version of the webpage that python can understand
soup = bs(page.text, 'html.parser')
#find specific table of the webpage (name of tag,class_= first word in class tag)
table = soup.find('table', class_='wikitable')

#Find all the table headers (th elements).
#Remove the footnotes/references from the header cell labels.
# equivalent to below headers = [th.text.strip().split('[')[0] for th in table.find_all('th')]
header = []
for th in table.find_all('th'):
    cl = th.text.strip().split('[')[0]
    headers.append(cl)

print(headers)

#There are two subheaders under Land Area. We need to make some adjustments to our headers.
lahead = headers[-4]
headers[-4] = lahead + ' sq mi'

#the list.insert() method adds an element to the list at a specified location.
headers.insert(-3, lahead + ' km2')

#Remove the last two elements from the headers list.
headers = headers[:-2]
print(headers)
# Out:
# ['Name', 'Type', 'County', 'Year established', 'Year incorporated', 'Form of government', 'Population(2010)', 'Population(2000)', 'Change', 'Land area(2010)', 'Population density', 'sq mi', 'km2']
# ['Name', 'Type', 'County', 'Year established', 'Year incorporated', 'Form of government', 'Population(2010)', 'Population(2000)', 'Change', 'Land area(2010) sq mi', 'Land area(2010) km2', 'Population density']

# %%
ridata = []
for row in table.find_all('tr')[2:]:
    #    rowdata = [cell.text.strip() for cell in row.find_all('td')]
    rowdata = []
    for cell in row.find_all('td'):
        rowdata.append(cell.text.strip())
    ridata.append(dict(zip(headers, rowdata)))

ridata
# Out:
# [{'Name': 'Barrington',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1653',
#   'Year incorporated': '1770',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,310',
#   'Population(2000)': '16,819',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '8.22',
#   'Land area(2010) km2': '21.3',
#   'Population density': '1,984.2/sq\xa0mi (766.1/km2)'},
#  {'Name': 'Bristol',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1680',
#   'Year incorporated': '1746',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,954',
#   'Population(2000)': '22,469',
#   'Change': '+2.2%',
#   'Land area(2010) sq mi': '9.82',
#   'Land area(2010) km2': '25.4',
#   'Population density': '2,337.5/sq\xa0mi (902.5/km2)'},
#  {'Name': 'Burrillville',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1806',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,955',
#   'Population(2000)': '15,796',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '55.03',
#   'Land area(2010) km2': '142.5',
#   'Population density': '289.9/sq\xa0mi (111.9/km2)'},
#  {'Name': 'Central Falls',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1895',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '19,376',
#   'Population(2000)': '18,928',
#   'Change': '+2.4%',
#   'Land area(2010) sq mi': '1.20',
#   'Land area(2010) km2': '3.1',
#   'Population density': '16,146.7/sq\xa0mi (6,234.3/km2)'},
#  {'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Coventry',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1743[b]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '35,014',
#   'Population(2000)': '33,668',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '59.05',
#   'Land area(2010) km2': '152.9',
#   'Population density': '593.0/sq\xa0mi (228.9/km2)'},
#  {'Name': 'Cranston',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1754',
#   'Year incorporated': '1910',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '80,387',
#   'Population(2000)': '79,269',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '28.34',
#   'Land area(2010) km2': '73.4',
#   'Population density': '2,836.5/sq\xa0mi (1,095.2/km2)'},
#  {'Name': 'Cumberland',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1746',
#   'Year incorporated': '1746',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '33,506',
#   'Population(2000)': '31,840',
#   'Change': '+5.2%',
#   'Land area(2010) sq mi': '26.45',
#   'Land area(2010) km2': '68.5',
#   'Population density': '1,266.8/sq\xa0mi (489.1/km2)'},
#  {'Name': 'East Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1677',
#   'Year incorporated': '1677[c]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '13,146',
#   'Population(2000)': '12,948',
#   'Change': '+1.5%',
#   'Land area(2010) sq mi': '16.39',
#   'Land area(2010) km2': '42.4',
#   'Population density': '802.1/sq\xa0mi (309.7/km2)'},
#  {'Name': 'East Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1812',
#   'Year incorporated': '1958',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '47,037',
#   'Population(2000)': '48,688',
#   'Change': '−3.4%',
#   'Land area(2010) sq mi': '13.24',
#   'Land area(2010) km2': '34.3',
#   'Population density': '3,552.6/sq\xa0mi (1,371.7/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'Foster',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1781',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '4,606',
#   'Population(2000)': '4,274',
#   'Change': '+7.8%',
#   'Land area(2010) sq mi': '50.80',
#   'Land area(2010) km2': '131.6',
#   'Population density': '90.7/sq\xa0mi (35.0/km2)'},
#  {'Name': 'Glocester',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1639',
#   'Year incorporated': '1730–1731',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '9,746',
#   'Population(2000)': '9,948',
#   'Change': '−2.0%',
#   'Land area(2010) sq mi': '54.18',
#   'Land area(2010) km2': '140.3',
#   'Population density': '179.9/sq\xa0mi (69.5/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Jamestown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1678',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '5,405',
#   'Population(2000)': '5,622',
#   'Change': '−3.9%',
#   'Land area(2010) sq mi': '9.45',
#   'Land area(2010) km2': '24.5',
#   'Population density': '572.0/sq\xa0mi (220.8/km2)'},
#  {'Name': 'Johnston',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1759',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '28,769',
#   'Population(2000)': '28,195',
#   'Change': '+2.0%',
#   'Land area(2010) sq mi': '23.43',
#   'Land area(2010) km2': '60.7',
#   'Population density': '1,227.9/sq\xa0mi (474.1/km2)'},
#  {'Name': 'Lincoln',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1650',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,105',
#   'Population(2000)': '20,898',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '18.12',
#   'Land area(2010) km2': '46.9',
#   'Population density': '1,164.7/sq\xa0mi (449.7/km2)'},
#  {'Name': 'Little Compton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1682',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '3,492',
#   'Population(2000)': '3,593',
#   'Change': '−2.8%',
#   'Land area(2010) sq mi': '20.52',
#   'Land area(2010) km2': '53.1',
#   'Population density': '170.2/sq\xa0mi (65.7/km2)'},
#  {'Name': 'Middletown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1743',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,150',
#   'Population(2000)': '17,334',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '12.72',
#   'Land area(2010) km2': '32.9',
#   'Population density': '1,269.7/sq\xa0mi (490.2/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'},
#  {'Name': 'Newport',
#   'Type': 'City',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1784[e]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '24,672',
#   'Population(2000)': '26,475',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '7.67',
#   'Land area(2010) km2': '19.9',
#   'Population density': '3,216.7/sq\xa0mi (1,242.0/km2)'},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'North Providence',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1765',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '32,078',
#   'Population(2000)': '32,411',
#   'Change': '−1.0%',
#   'Land area(2010) sq mi': '5.62',
#   'Land area(2010) km2': '14.6',
#   'Population density': '5,707.8/sq\xa0mi (2,203.8/km2)'},
#  {'Name': 'North Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '11,967',
#   'Population(2000)': '10,618',
#   'Change': '+12.7%',
#   'Land area(2010) sq mi': '23.80',
#   'Land area(2010) km2': '61.6',
#   'Population density': '502.8/sq\xa0mi (194.1/km2)'},
#  {'Name': 'Pawtucket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1671',
#   'Year incorporated': '1954',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '71,148',
#   'Population(2000)': '72,958',
#   'Change': '−2.5%',
#   'Land area(2010) sq mi': '8.68',
#   'Land area(2010) km2': '22.5',
#   'Population density': '8,196.8/sq\xa0mi (3,164.8/km2)'},
#  {'Name': 'Portsmouth',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1638',
#   'Year incorporated': '1640[f]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '17,389',
#   'Population(2000)': '17,149',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '22.98',
#   'Land area(2010) km2': '59.5',
#   'Population density': '756.7/sq\xa0mi (292.2/km2)'},
#  {'Name': 'Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1832',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '178,042',
#   'Population(2000)': '173,618',
#   'Change': '+2.5%',
#   'Land area(2010) sq mi': '18.40',
#   'Land area(2010) km2': '47.7',
#   'Population density': '9,676.2/sq\xa0mi (3,736.0/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'Scituate',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '10,329',
#   'Population(2000)': '10,324',
#   'Change': '0.0%',
#   'Land area(2010) sq mi': '48.16',
#   'Land area(2010) km2': '124.7',
#   'Population density': '214.5/sq\xa0mi (82.8/km2)'},
#  {'Name': 'Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,430',
#   'Population(2000)': '20,613',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '26.31',
#   'Land area(2010) km2': '68.1',
#   'Population density': '814.5/sq\xa0mi (314.5/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'Tiverton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1694',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '15,780',
#   'Population(2000)': '15,260',
#   'Change': '+3.4%',
#   'Land area(2010) sq mi': '29.05',
#   'Land area(2010) km2': '75.2',
#   'Population density': '543.2/sq\xa0mi (209.7/km2)'},
#  {'Name': 'Warren',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1620',
#   'Year incorporated': '1747',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '10,611',
#   'Population(2000)': '11,360',
#   'Change': '−6.6%',
#   'Land area(2010) sq mi': '6.12',
#   'Land area(2010) km2': '15.9',
#   'Population density': '1,733.8/sq\xa0mi (669.4/km2)'},
#  {'Name': 'Warwick',
#   'Type': 'City',
#   'County': 'Kent',
#   'Year established': '1642',
#   'Year incorporated': '1931',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '82,672',
#   'Population(2000)': '85,808',
#   'Change': '−3.7%',
#   'Land area(2010) sq mi': '35.04',
#   'Land area(2010) km2': '90.8',
#   'Population density': '2,359.4/sq\xa0mi (911.0/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'},
#  {'Name': 'West Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1741',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,135',
#   'Population(2000)': '5,085',
#   'Change': '+20.6%',
#   'Land area(2010) sq mi': '50.26',
#   'Land area(2010) km2': '130.2',
#   'Population density': '122.1/sq\xa0mi (47.1/km2)'},
#  {'Name': 'West Warwick',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1648',
#   'Year incorporated': '1913',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '29,191',
#   'Population(2000)': '29,581',
#   'Change': '−1.3%',
#   'Land area(2010) sq mi': '7.79',
#   'Land area(2010) km2': '20.2',
#   'Population density': '3,747.2/sq\xa0mi (1,446.8/km2)'},
#  {'Name': 'Woonsocket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1867',
#   'Year incorporated': '1888',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '41,186',
#   'Population(2000)': '43,224',
#   'Change': '−4.7%',
#   'Land area(2010) sq mi': '7.74',
#   'Land area(2010) km2': '20.0',
#   'Population density': '5,321.2/sq\xa0mi (2,054.5/km2)'},
#  {'Name': 'Total',
#   'Type': '—',
#   'County': '—',
#   'Year established': '—',
#   'Year incorporated': '—',
#   'Form of government': '—',
#   'Population(2010)': '1,052,567',
#   'Population(2000)': '1,048,319',
#   'Change': '+0.4%',
#   'Land area(2010) sq mi': '1,033.82',
#   'Land area(2010) km2': '2,677.6',
#   'Population density': '1,018.13/sq\xa0mi (393.10/km2)'}]

# %% [markdown]
# #### Practice
# Find another table on Wikipedia (try searching for "list of...". Import that table, as I have the RI towns list.

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_Criminal_Minds_episodes')
page
# Out:
# <Response [200]>

# %%
soup = bs(page.text, 'html.parser')
table = soup.find('table', class_='wikitable plainrowheaders wikiepisodetable')
headers = []
for th in table.find_all('th'):
    cl = th.text.strip().split('[')[0]
    headers.append(cl)
headers = headers[:-22]
headers = headers[1:]
print(headers)

season1data = []
for row in table.find_all('tr')[1:]:
    rowdata = [cell.text.strip().split('[')[0] for cell in row.find_all('td')]
    season1data.append(dict(zip(headers, rowdata)))
    
season1data
# Out:
# ['No. inseason', 'Title', 'Directed by', 'Written by', 'Original air date', 'Prod.code', 'US viewers(millions)']
# [{'No. inseason': '1',
#   'Title': '"Extreme Aggressor"',
#   'Directed by': 'Richard Shepard',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'September\xa022,\xa02005\xa0(2005-09-22)',
#   'Prod.code': '101',
#   'US viewers(millions)': '19.57'},
#  {'No. inseason': '2',
#   'Title': '"Compulsion"',
#   'Directed by': 'Charles Haid',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'September\xa028,\xa02005\xa0(2005-09-28)',
#   'Prod.code': '102',
#   'US viewers(millions)': '10.57'},
#  {'No. inseason': '3',
#   'Title': '"Won\'t Get Fooled Again"',
#   'Directed by': 'Kevin Bray',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'October\xa05,\xa02005\xa0(2005-10-05)',
#   'Prod.code': '103',
#   'US viewers(millions)': '11.98'},
#  {'No. inseason': '4',
#   'Title': '"Plain Sight"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'October\xa012,\xa02005\xa0(2005-10-12)',
#   'Prod.code': '104',
#   'US viewers(millions)': '13.76'},
#  {'No. inseason': '5',
#   'Title': '"Broken Mirror"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Judith McCreary',
#   'Original air date': 'October\xa019,\xa02005\xa0(2005-10-19)',
#   'Prod.code': '105',
#   'US viewers(millions)': '12.79'},
#  {'No. inseason': '6',
#   'Title': '"L.D.S.K."',
#   'Directed by': 'Ernest Dickerson',
#   'Written by': 'Andrew Wilder',
#   'Original air date': 'November\xa02,\xa02005\xa0(2005-11-02)',
#   'Prod.code': '106',
#   'US viewers(millions)': '16.22'},
#  {'No. inseason': '7',
#   'Title': '"The Fox"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'November\xa09,\xa02005\xa0(2005-11-09)',
#   'Prod.code': '107',
#   'US viewers(millions)': '15.09'},
#  {'No. inseason': '8',
#   'Title': '"Natural Born Killer"',
#   'Directed by': 'Peter Ellis',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'November\xa016,\xa02005\xa0(2005-11-16)',
#   'Prod.code': '108',
#   'US viewers(millions)': '14.36'},
#  {'No. inseason': '9',
#   'Title': '"Derailed"',
#   'Directed by': 'Félix Alcalá',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'November\xa023,\xa02005\xa0(2005-11-23)',
#   'Prod.code': '109',
#   'US viewers(millions)': '12.83'},
#  {'No. inseason': '10',
#   'Title': '"The Popular Kids"',
#   'Directed by': 'Andy Wolk',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'November\xa030,\xa02005\xa0(2005-11-30)',
#   'Prod.code': '110',
#   'US viewers(millions)': '15.56'},
#  {'No. inseason': '11',
#   'Title': '"Blood Hungry"',
#   'Directed by': 'Charles Haid',
#   'Written by': 'Ed Napier',
#   'Original air date': 'December\xa014,\xa02005\xa0(2005-12-14)',
#   'Prod.code': '111',
#   'US viewers(millions)': '15.23'},
#  {'No. inseason': '12',
#   'Title': '"What Fresh Hell"',
#   'Directed by': 'Adam Davidson',
#   'Written by': 'Judith McCreary',
#   'Original air date': 'January\xa011,\xa02006\xa0(2006-01-11)',
#   'Prod.code': '112',
#   'US viewers(millions)': '15.92'},
#  {'No. inseason': '13',
#   'Title': '"Poison"',
#   'Directed by': 'Thomas J. Wright',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'January\xa018,\xa02006\xa0(2006-01-18)',
#   'Prod.code': '113',
#   'US viewers(millions)': '14.65'},
#  {'No. inseason': '14',
#   'Title': '"Riding the Lightning"',
#   'Directed by': 'Chris Long',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'January\xa025,\xa02006\xa0(2006-01-25)',
#   'Prod.code': '114',
#   'US viewers(millions)': '14.10'},
#  {'No. inseason': '15',
#   'Title': '"Unfinished Business"',
#   'Directed by': 'J. Miller Tobin',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'March\xa01,\xa02006\xa0(2006-03-01)',
#   'Prod.code': '115',
#   'US viewers(millions)': '11.72'},
#  {'No. inseason': '16',
#   'Title': '"The Tribe"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Andrew Wilder',
#   'Original air date': 'March\xa08,\xa02006\xa0(2006-03-08)',
#   'Prod.code': '116',
#   'US viewers(millions)': '15.27'},
#  {'No. inseason': '17',
#   'Title': '"A Real Rain"',
#   'Directed by': 'Gloria Muzio',
#   'Written by': 'Chris Mundy',
#   'Original air date': 'March\xa022,\xa02006\xa0(2006-03-22)',
#   'Prod.code': '117',
#   'US viewers(millions)': '13.03'},
#  {'No. inseason': '18',
#   'Title': '"Somebody\'s Watching"',
#   'Directed by': 'Paul Shapiro',
#   'Written by': 'Ed Napier',
#   'Original air date': 'March\xa029,\xa02006\xa0(2006-03-29)',
#   'Prod.code': '118',
#   'US viewers(millions)': '12.54'},
#  {'No. inseason': '19',
#   'Title': '"Machismo"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'April\xa012,\xa02006\xa0(2006-04-12)',
#   'Prod.code': '119',
#   'US viewers(millions)': '11.76'},
#  {'No. inseason': '20',
#   'Title': '"Charm and Harm"',
#   'Directed by': 'Félix Alcalá',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'April\xa019,\xa02006\xa0(2006-04-19)',
#   'Prod.code': '120',
#   'US viewers(millions)': '13.53'},
#  {'No. inseason': '21',
#   'Title': '"Secrets and Lies"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'May\xa03,\xa02006\xa0(2006-05-03)',
#   'Prod.code': '121',
#   'US viewers(millions)': '12.17'},
#  {'No. inseason': '22',
#   'Title': '"The Fisher King, Part 1"',
#   'Directed by': 'Edward Allen Bernero',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'May\xa010,\xa02006\xa0(2006-05-10)',
#   'Prod.code': '122',
#   'US viewers(millions)': '12.67'}]

# %% [markdown]
# ### Working with lists of data

# %% [markdown]
# #### Selecting "rows" or "columns"

# %% [markdown]
# Picking a single row by its index is easy--we've been doing this since the second class.

# %%
ridata[5]
# Out:
# {'Name': 'Coventry',
#  'Type': 'Town',
#  'County': 'Kent',
#  'Year established': '1639',
#  'Year incorporated': '1743[b]',
#  'Form of government': 'Council–manager',
#  'Population(2010)': '35,014',
#  'Population(2000)': '33,668',
#  'Change': '+4.0%',
#  'Land area(2010) sq mi': '59.05',
#  'Land area(2010) km2': '152.9',
#  'Population density': '593.0/sq\xa0mi (228.9/km2)'}

# %%
print(ridata[-1])
del(ridata[-1])
# Out:
# {'Name': 'Total', 'Type': '—', 'County': '—', 'Year established': '—', 'Year incorporated': '—', 'Form of government': '—', 'Population(2010)': '1,052,567', 'Population(2000)': '1,048,319', 'Change': '+0.4%', 'Land area(2010) sq mi': '1,033.82', 'Land area(2010) km2': '2,677.6', 'Population density': '1,018.13/sq\xa0mi (393.10/km2)'}

# %% [markdown]
# We can also choose one or more rows using a list comprehension.

# %%
[x for x in ridata if x['County']=="Washington"]
# Out:
# [{'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'}]

# %% [markdown]
# Another option is the [`filter()`](https://docs.python.org/3/library/functions.html#filter) function. For this we need a new language feature: [_lambda_ expressions](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions). These are small functions that can be used as function or method arguments without first declaring them.
#
# Here's the equivalent of the last expression using `filter()`

# %%
list(filter(lambda x: x['County'] == 'Washington', ridata))
# Out:
# [{'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'}]

# %% [markdown]
# `filter()` takes two arguments:
#
# 1. A function that returns `True` if we should keep the list (or other iterable) item or `False` otherwise; and
# 2. our list.
#
# Our first argument above is a lambda function:
#
# `lambda x: x['County'] == 'Washington'`
#
# This is simply a shorthand method of creating a function and using it once. We can get the same effect this way:

# %%
def wash_county(x):
    return x['County'] == 'Washington'

list(filter(wash_county, ridata))
# Out:
# [{'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'}]

# %% [markdown]
# We can select a single "column" with a simple list comprehension:

# %%
[row['Name'] for row in ridata]
# Out:
# ['Barrington',
#  'Bristol',
#  'Burrillville',
#  'Central Falls',
#  'Charlestown',
#  'Coventry',
#  'Cranston',
#  'Cumberland',
#  'East Greenwich',
#  'East Providence',
#  'Exeter',
#  'Foster',
#  'Glocester',
#  'Hopkinton',
#  'Jamestown',
#  'Johnston',
#  'Lincoln',
#  'Little Compton',
#  'Middletown',
#  'Narragansett',
#  'Newport',
#  'New Shoreham',
#  'North Kingstown',
#  'North Providence',
#  'North Smithfield',
#  'Pawtucket',
#  'Portsmouth',
#  'Providence',
#  'Richmond',
#  'Scituate',
#  'Smithfield',
#  'South Kingstown',
#  'Tiverton',
#  'Warren',
#  'Warwick',
#  'Westerly',
#  'West Greenwich',
#  'West Warwick',
#  'Woonsocket']

# %% [markdown]
# ##### Practice
# Experiment with selecting rows or columns from one of the datasets you've loaded (your data, `personsx.csv`, or your Wikipedia table).

# %%
season1data[3:6]
# Out:
# [{'No. inseason': '4',
#   'Title': '"Plain Sight"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'October\xa012,\xa02005\xa0(2005-10-12)',
#   'Prod.code': '104',
#   'US viewers(millions)': '13.76'},
#  {'No. inseason': '5',
#   'Title': '"Broken Mirror"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Judith McCreary',
#   'Original air date': 'October\xa019,\xa02005\xa0(2005-10-19)',
#   'Prod.code': '105',
#   'US viewers(millions)': '12.79'},
#  {'No. inseason': '6',
#   'Title': '"L.D.S.K."',
#   'Directed by': 'Ernest Dickerson',
#   'Written by': 'Andrew Wilder',
#   'Original air date': 'November\xa02,\xa02005\xa0(2005-11-02)',
#   'Prod.code': '106',
#   'US viewers(millions)': '16.22'}]

# %%
[row['Directed by'] for row in season1data]
# Out:
# ['Richard Shepard',
#  'Charles Haid',
#  'Kevin Bray',
#  'Matt Earl Beesley',
#  'Guy Norman Bee',
#  'Ernest Dickerson',
#  'Guy Norman Bee',
#  'Peter Ellis',
#  'Félix Alcalá',
#  'Andy Wolk',
#  'Charles Haid',
#  'Adam Davidson',
#  'Thomas J. Wright',
#  'Chris Long',
#  'J. Miller Tobin',
#  'Matt Earl Beesley',
#  'Gloria Muzio',
#  'Paul Shapiro',
#  'Guy Norman Bee',
#  'Félix Alcalá',
#  'Matt Earl Beesley',
#  'Edward Allen Bernero']

# %% [markdown]
# #### [Sorting](https://docs.python.org/3/howto/sorting.html)
#
# Sorting simple lists is simple.

# %%
from random import randrange
somelist = [randrange(100) for x in range(10)]
print(somelist)
print(sorted(somelist))
# Out:
# [97, 70, 68, 97, 2, 13, 31, 64, 10, 58]
# [2, 10, 13, 31, 58, 64, 68, 70, 97, 97]

# %% [markdown]
# Our lists of dictionaries are slightly more complex. We must provide a `key` argument. We can use a `lambda`.

# %%
sorted(ridata, key=lambda muni: muni['Year established'])
# Out:
# [{'Name': 'Warren',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1620',
#   'Year incorporated': '1747',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '10,611',
#   'Population(2000)': '11,360',
#   'Change': '−6.6%',
#   'Land area(2010) sq mi': '6.12',
#   'Land area(2010) km2': '15.9',
#   'Population density': '1,733.8/sq\xa0mi (669.4/km2)'},
#  {'Name': 'Foster',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1781',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '4,606',
#   'Population(2000)': '4,274',
#   'Change': '+7.8%',
#   'Land area(2010) sq mi': '50.80',
#   'Land area(2010) km2': '131.6',
#   'Population density': '90.7/sq\xa0mi (35.0/km2)'},
#  {'Name': 'Johnston',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1759',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '28,769',
#   'Population(2000)': '28,195',
#   'Change': '+2.0%',
#   'Land area(2010) sq mi': '23.43',
#   'Land area(2010) km2': '60.7',
#   'Population density': '1,227.9/sq\xa0mi (474.1/km2)'},
#  {'Name': 'North Providence',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1765',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '32,078',
#   'Population(2000)': '32,411',
#   'Change': '−1.0%',
#   'Land area(2010) sq mi': '5.62',
#   'Land area(2010) km2': '14.6',
#   'Population density': '5,707.8/sq\xa0mi (2,203.8/km2)'},
#  {'Name': 'Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1832',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '178,042',
#   'Population(2000)': '173,618',
#   'Change': '+2.5%',
#   'Land area(2010) sq mi': '18.40',
#   'Land area(2010) km2': '47.7',
#   'Population density': '9,676.2/sq\xa0mi (3,736.0/km2)'},
#  {'Name': 'Scituate',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '10,329',
#   'Population(2000)': '10,324',
#   'Change': '0.0%',
#   'Land area(2010) sq mi': '48.16',
#   'Land area(2010) km2': '124.7',
#   'Population density': '214.5/sq\xa0mi (82.8/km2)'},
#  {'Name': 'Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,430',
#   'Population(2000)': '20,613',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '26.31',
#   'Land area(2010) km2': '68.1',
#   'Population density': '814.5/sq\xa0mi (314.5/km2)'},
#  {'Name': 'Portsmouth',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1638',
#   'Year incorporated': '1640[f]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '17,389',
#   'Population(2000)': '17,149',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '22.98',
#   'Land area(2010) km2': '59.5',
#   'Population density': '756.7/sq\xa0mi (292.2/km2)'},
#  {'Name': 'Coventry',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1743[b]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '35,014',
#   'Population(2000)': '33,668',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '59.05',
#   'Land area(2010) km2': '152.9',
#   'Population density': '593.0/sq\xa0mi (228.9/km2)'},
#  {'Name': 'Glocester',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1639',
#   'Year incorporated': '1730–1731',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '9,746',
#   'Population(2000)': '9,948',
#   'Change': '−2.0%',
#   'Land area(2010) sq mi': '54.18',
#   'Land area(2010) km2': '140.3',
#   'Population density': '179.9/sq\xa0mi (69.5/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Jamestown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1678',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '5,405',
#   'Population(2000)': '5,622',
#   'Change': '−3.9%',
#   'Land area(2010) sq mi': '9.45',
#   'Land area(2010) km2': '24.5',
#   'Population density': '572.0/sq\xa0mi (220.8/km2)'},
#  {'Name': 'Middletown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1743',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,150',
#   'Population(2000)': '17,334',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '12.72',
#   'Land area(2010) km2': '32.9',
#   'Population density': '1,269.7/sq\xa0mi (490.2/km2)'},
#  {'Name': 'Newport',
#   'Type': 'City',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1784[e]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '24,672',
#   'Population(2000)': '26,475',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '7.67',
#   'Land area(2010) km2': '19.9',
#   'Population density': '3,216.7/sq\xa0mi (1,242.0/km2)'},
#  {'Name': 'West Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1741',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,135',
#   'Population(2000)': '5,085',
#   'Change': '+20.6%',
#   'Land area(2010) sq mi': '50.26',
#   'Land area(2010) km2': '130.2',
#   'Population density': '122.1/sq\xa0mi (47.1/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'Warwick',
#   'Type': 'City',
#   'County': 'Kent',
#   'Year established': '1642',
#   'Year incorporated': '1931',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '82,672',
#   'Population(2000)': '85,808',
#   'Change': '−3.7%',
#   'Land area(2010) sq mi': '35.04',
#   'Land area(2010) km2': '90.8',
#   'Population density': '2,359.4/sq\xa0mi (911.0/km2)'},
#  {'Name': 'West Warwick',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1648',
#   'Year incorporated': '1913',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '29,191',
#   'Population(2000)': '29,581',
#   'Change': '−1.3%',
#   'Land area(2010) sq mi': '7.79',
#   'Land area(2010) km2': '20.2',
#   'Population density': '3,747.2/sq\xa0mi (1,446.8/km2)'},
#  {'Name': 'Lincoln',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1650',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,105',
#   'Population(2000)': '20,898',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '18.12',
#   'Land area(2010) km2': '46.9',
#   'Population density': '1,164.7/sq\xa0mi (449.7/km2)'},
#  {'Name': 'Barrington',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1653',
#   'Year incorporated': '1770',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,310',
#   'Population(2000)': '16,819',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '8.22',
#   'Land area(2010) km2': '21.3',
#   'Population density': '1,984.2/sq\xa0mi (766.1/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'Pawtucket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1671',
#   'Year incorporated': '1954',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '71,148',
#   'Population(2000)': '72,958',
#   'Change': '−2.5%',
#   'Land area(2010) sq mi': '8.68',
#   'Land area(2010) km2': '22.5',
#   'Population density': '8,196.8/sq\xa0mi (3,164.8/km2)'},
#  {'Name': 'East Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1677',
#   'Year incorporated': '1677[c]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '13,146',
#   'Population(2000)': '12,948',
#   'Change': '+1.5%',
#   'Land area(2010) sq mi': '16.39',
#   'Land area(2010) km2': '42.4',
#   'Population density': '802.1/sq\xa0mi (309.7/km2)'},
#  {'Name': 'Bristol',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1680',
#   'Year incorporated': '1746',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,954',
#   'Population(2000)': '22,469',
#   'Change': '+2.2%',
#   'Land area(2010) sq mi': '9.82',
#   'Land area(2010) km2': '25.4',
#   'Population density': '2,337.5/sq\xa0mi (902.5/km2)'},
#  {'Name': 'Little Compton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1682',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '3,492',
#   'Population(2000)': '3,593',
#   'Change': '−2.8%',
#   'Land area(2010) sq mi': '20.52',
#   'Land area(2010) km2': '53.1',
#   'Population density': '170.2/sq\xa0mi (65.7/km2)'},
#  {'Name': 'Tiverton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1694',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '15,780',
#   'Population(2000)': '15,260',
#   'Change': '+3.4%',
#   'Land area(2010) sq mi': '29.05',
#   'Land area(2010) km2': '75.2',
#   'Population density': '543.2/sq\xa0mi (209.7/km2)'},
#  {'Name': 'Burrillville',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1806',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,955',
#   'Population(2000)': '15,796',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '55.03',
#   'Land area(2010) km2': '142.5',
#   'Population density': '289.9/sq\xa0mi (111.9/km2)'},
#  {'Name': 'Central Falls',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1895',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '19,376',
#   'Population(2000)': '18,928',
#   'Change': '+2.4%',
#   'Land area(2010) sq mi': '1.20',
#   'Land area(2010) km2': '3.1',
#   'Population density': '16,146.7/sq\xa0mi (6,234.3/km2)'},
#  {'Name': 'North Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '11,967',
#   'Population(2000)': '10,618',
#   'Change': '+12.7%',
#   'Land area(2010) sq mi': '23.80',
#   'Land area(2010) km2': '61.6',
#   'Population density': '502.8/sq\xa0mi (194.1/km2)'},
#  {'Name': 'Cumberland',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1746',
#   'Year incorporated': '1746',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '33,506',
#   'Population(2000)': '31,840',
#   'Change': '+5.2%',
#   'Land area(2010) sq mi': '26.45',
#   'Land area(2010) km2': '68.5',
#   'Population density': '1,266.8/sq\xa0mi (489.1/km2)'},
#  {'Name': 'Cranston',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1754',
#   'Year incorporated': '1910',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '80,387',
#   'Population(2000)': '79,269',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '28.34',
#   'Land area(2010) km2': '73.4',
#   'Population density': '2,836.5/sq\xa0mi (1,095.2/km2)'},
#  {'Name': 'East Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1812',
#   'Year incorporated': '1958',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '47,037',
#   'Population(2000)': '48,688',
#   'Change': '−3.4%',
#   'Land area(2010) sq mi': '13.24',
#   'Land area(2010) km2': '34.3',
#   'Population density': '3,552.6/sq\xa0mi (1,371.7/km2)'},
#  {'Name': 'Woonsocket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1867',
#   'Year incorporated': '1888',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '41,186',
#   'Population(2000)': '43,224',
#   'Change': '−4.7%',
#   'Land area(2010) sq mi': '7.74',
#   'Land area(2010) km2': '20.0',
#   'Population density': '5,321.2/sq\xa0mi (2,054.5/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'}]

# %% [markdown]
# We can also use `itemgetter` from the `operator` module:

# %%
from operator import itemgetter
sorted(ridata, key=itemgetter('Population(2010)'))
# Out:
# [{'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1664',
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '1,051',
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': '9.08',
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)'},
#  {'Name': 'Scituate',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '10,329',
#   'Population(2000)': '10,324',
#   'Change': '0.0%',
#   'Land area(2010) sq mi': '48.16',
#   'Land area(2010) km2': '124.7',
#   'Population density': '214.5/sq\xa0mi (82.8/km2)'},
#  {'Name': 'Warren',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1620',
#   'Year incorporated': '1747',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '10,611',
#   'Population(2000)': '11,360',
#   'Change': '−6.6%',
#   'Land area(2010) sq mi': '6.12',
#   'Land area(2010) km2': '15.9',
#   'Population density': '1,733.8/sq\xa0mi (669.4/km2)'},
#  {'Name': 'North Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '11,967',
#   'Population(2000)': '10,618',
#   'Change': '+12.7%',
#   'Land area(2010) sq mi': '23.80',
#   'Land area(2010) km2': '61.6',
#   'Population density': '502.8/sq\xa0mi (194.1/km2)'},
#  {'Name': 'East Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1677',
#   'Year incorporated': '1677[c]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '13,146',
#   'Population(2000)': '12,948',
#   'Change': '+1.5%',
#   'Land area(2010) sq mi': '16.39',
#   'Land area(2010) km2': '42.4',
#   'Population density': '802.1/sq\xa0mi (309.7/km2)'},
#  {'Name': 'Tiverton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1694',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '15,780',
#   'Population(2000)': '15,260',
#   'Change': '+3.4%',
#   'Land area(2010) sq mi': '29.05',
#   'Land area(2010) km2': '75.2',
#   'Population density': '543.2/sq\xa0mi (209.7/km2)'},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1888',
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,868',
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '13.89',
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)'},
#  {'Name': 'Burrillville',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1806',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '15,955',
#   'Population(2000)': '15,796',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '55.03',
#   'Land area(2010) km2': '142.5',
#   'Population density': '289.9/sq\xa0mi (111.9/km2)'},
#  {'Name': 'Middletown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1743',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,150',
#   'Population(2000)': '17,334',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '12.72',
#   'Land area(2010) km2': '32.9',
#   'Population density': '1,269.7/sq\xa0mi (490.2/km2)'},
#  {'Name': 'Barrington',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1653',
#   'Year incorporated': '1770',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '16,310',
#   'Population(2000)': '16,819',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': '8.22',
#   'Land area(2010) km2': '21.3',
#   'Population density': '1,984.2/sq\xa0mi (766.1/km2)'},
#  {'Name': 'Portsmouth',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1638',
#   'Year incorporated': '1640[f]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '17,389',
#   'Population(2000)': '17,149',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '22.98',
#   'Land area(2010) km2': '59.5',
#   'Population density': '756.7/sq\xa0mi (292.2/km2)'},
#  {'Name': 'Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1832',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '178,042',
#   'Population(2000)': '173,618',
#   'Change': '+2.5%',
#   'Land area(2010) sq mi': '18.40',
#   'Land area(2010) km2': '47.7',
#   'Population density': '9,676.2/sq\xa0mi (3,736.0/km2)'},
#  {'Name': 'Central Falls',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1730',
#   'Year incorporated': '1895',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '19,376',
#   'Population(2000)': '18,928',
#   'Change': '+2.4%',
#   'Land area(2010) sq mi': '1.20',
#   'Land area(2010) km2': '3.1',
#   'Population density': '16,146.7/sq\xa0mi (6,234.3/km2)'},
#  {'Name': 'Lincoln',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1650',
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,105',
#   'Population(2000)': '20,898',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': '18.12',
#   'Land area(2010) km2': '46.9',
#   'Population density': '1,164.7/sq\xa0mi (449.7/km2)'},
#  {'Name': 'Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1730',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '21,430',
#   'Population(2000)': '20,613',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '26.31',
#   'Land area(2010) km2': '68.1',
#   'Population density': '814.5/sq\xa0mi (314.5/km2)'},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1661',
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,787',
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': '29.52',
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)'},
#  {'Name': 'Bristol',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': '1680',
#   'Year incorporated': '1746',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '22,954',
#   'Population(2000)': '22,469',
#   'Change': '+2.2%',
#   'Land area(2010) sq mi': '9.82',
#   'Land area(2010) km2': '25.4',
#   'Population density': '2,337.5/sq\xa0mi (902.5/km2)'},
#  {'Name': 'Newport',
#   'Type': 'City',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1784[e]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '24,672',
#   'Population(2000)': '26,475',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': '7.67',
#   'Land area(2010) km2': '19.9',
#   'Population density': '3,216.7/sq\xa0mi (1,242.0/km2)'},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '26,486',
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': '43.14',
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)'},
#  {'Name': 'Johnston',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1759',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '28,769',
#   'Population(2000)': '28,195',
#   'Change': '+2.0%',
#   'Land area(2010) sq mi': '23.43',
#   'Land area(2010) km2': '60.7',
#   'Population density': '1,227.9/sq\xa0mi (474.1/km2)'},
#  {'Name': 'West Warwick',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1648',
#   'Year incorporated': '1913',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '29,191',
#   'Population(2000)': '29,581',
#   'Change': '−1.3%',
#   'Land area(2010) sq mi': '7.79',
#   'Land area(2010) km2': '20.2',
#   'Population density': '3,747.2/sq\xa0mi (1,446.8/km2)'},
#  {'Name': 'Little Compton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1682',
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '3,492',
#   'Population(2000)': '3,593',
#   'Change': '−2.8%',
#   'Land area(2010) sq mi': '20.52',
#   'Land area(2010) km2': '53.1',
#   'Population density': '170.2/sq\xa0mi (65.7/km2)'},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1657',
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '30,639',
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': '56.45',
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)'},
#  {'Name': 'North Providence',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1765',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '32,078',
#   'Population(2000)': '32,411',
#   'Change': '−1.0%',
#   'Land area(2010) sq mi': '5.62',
#   'Land area(2010) km2': '14.6',
#   'Population density': '5,707.8/sq\xa0mi (2,203.8/km2)'},
#  {'Name': 'Cumberland',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1746',
#   'Year incorporated': '1746',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '33,506',
#   'Population(2000)': '31,840',
#   'Change': '+5.2%',
#   'Land area(2010) sq mi': '26.45',
#   'Land area(2010) km2': '68.5',
#   'Population density': '1,266.8/sq\xa0mi (489.1/km2)'},
#  {'Name': 'Coventry',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1743[b]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '35,014',
#   'Population(2000)': '33,668',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': '59.05',
#   'Land area(2010) km2': '152.9',
#   'Population density': '593.0/sq\xa0mi (228.9/km2)'},
#  {'Name': 'Foster',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1636',
#   'Year incorporated': '1781',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '4,606',
#   'Population(2000)': '4,274',
#   'Change': '+7.8%',
#   'Land area(2010) sq mi': '50.80',
#   'Land area(2010) km2': '131.6',
#   'Population density': '90.7/sq\xa0mi (35.0/km2)'},
#  {'Name': 'Woonsocket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1867',
#   'Year incorporated': '1888',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '41,186',
#   'Population(2000)': '43,224',
#   'Change': '−4.7%',
#   'Land area(2010) sq mi': '7.74',
#   'Land area(2010) km2': '20.0',
#   'Population density': '5,321.2/sq\xa0mi (2,054.5/km2)'},
#  {'Name': 'East Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1812',
#   'Year incorporated': '1958',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '47,037',
#   'Population(2000)': '48,688',
#   'Change': '−3.4%',
#   'Land area(2010) sq mi': '13.24',
#   'Land area(2010) km2': '34.3',
#   'Population density': '3,552.6/sq\xa0mi (1,371.7/km2)'},
#  {'Name': 'Jamestown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': '1639',
#   'Year incorporated': '1678',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '5,405',
#   'Population(2000)': '5,622',
#   'Change': '−3.9%',
#   'Land area(2010) sq mi': '9.45',
#   'Land area(2010) km2': '24.5',
#   'Population density': '572.0/sq\xa0mi (220.8/km2)'},
#  {'Name': 'West Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': '1639',
#   'Year incorporated': '1741',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,135',
#   'Population(2000)': '5,085',
#   'Change': '+20.6%',
#   'Land area(2010) sq mi': '50.26',
#   'Land area(2010) km2': '130.2',
#   'Population density': '122.1/sq\xa0mi (47.1/km2)'},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1641',
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '6,425',
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': '57.47',
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)'},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '7,708',
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': '40.29',
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)'},
#  {'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1669',
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': '7,827',
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': '36.45',
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)'},
#  {'Name': 'Pawtucket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1671',
#   'Year incorporated': '1954',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '71,148',
#   'Population(2000)': '72,958',
#   'Change': '−2.5%',
#   'Land area(2010) sq mi': '8.68',
#   'Land area(2010) km2': '22.5',
#   'Population density': '8,196.8/sq\xa0mi (3,164.8/km2)'},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': '1639',
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '8,188',
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': '42.95',
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)'},
#  {'Name': 'Cranston',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': '1754',
#   'Year incorporated': '1910',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '80,387',
#   'Population(2000)': '79,269',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': '28.34',
#   'Land area(2010) km2': '73.4',
#   'Population density': '2,836.5/sq\xa0mi (1,095.2/km2)'},
#  {'Name': 'Warwick',
#   'Type': 'City',
#   'County': 'Kent',
#   'Year established': '1642',
#   'Year incorporated': '1931',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': '82,672',
#   'Population(2000)': '85,808',
#   'Change': '−3.7%',
#   'Land area(2010) sq mi': '35.04',
#   'Land area(2010) km2': '90.8',
#   'Population density': '2,359.4/sq\xa0mi (911.0/km2)'},
#  {'Name': 'Glocester',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': '1639',
#   'Year incorporated': '1730–1731',
#   'Form of government': 'Town meeting',
#   'Population(2010)': '9,746',
#   'Population(2000)': '9,948',
#   'Change': '−2.0%',
#   'Land area(2010) sq mi': '54.18',
#   'Land area(2010) km2': '140.3',
#   'Population density': '179.9/sq\xa0mi (69.5/km2)'}]

# %% [markdown]
# ##### Practice
# Experiment with sorting your data.

# %%
sorted(season1data, key=lambda muni: muni['US viewers(millions)'])
# Out:
# [{'No. inseason': '2',
#   'Title': '"Compulsion"',
#   'Directed by': 'Charles Haid',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'September\xa028,\xa02005\xa0(2005-09-28)',
#   'Prod.code': '102',
#   'US viewers(millions)': '10.57'},
#  {'No. inseason': '15',
#   'Title': '"Unfinished Business"',
#   'Directed by': 'J. Miller Tobin',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'March\xa01,\xa02006\xa0(2006-03-01)',
#   'Prod.code': '115',
#   'US viewers(millions)': '11.72'},
#  {'No. inseason': '19',
#   'Title': '"Machismo"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'April\xa012,\xa02006\xa0(2006-04-12)',
#   'Prod.code': '119',
#   'US viewers(millions)': '11.76'},
#  {'No. inseason': '3',
#   'Title': '"Won\'t Get Fooled Again"',
#   'Directed by': 'Kevin Bray',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'October\xa05,\xa02005\xa0(2005-10-05)',
#   'Prod.code': '103',
#   'US viewers(millions)': '11.98'},
#  {'No. inseason': '21',
#   'Title': '"Secrets and Lies"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'May\xa03,\xa02006\xa0(2006-05-03)',
#   'Prod.code': '121',
#   'US viewers(millions)': '12.17'},
#  {'No. inseason': '18',
#   'Title': '"Somebody\'s Watching"',
#   'Directed by': 'Paul Shapiro',
#   'Written by': 'Ed Napier',
#   'Original air date': 'March\xa029,\xa02006\xa0(2006-03-29)',
#   'Prod.code': '118',
#   'US viewers(millions)': '12.54'},
#  {'No. inseason': '22',
#   'Title': '"The Fisher King, Part 1"',
#   'Directed by': 'Edward Allen Bernero',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'May\xa010,\xa02006\xa0(2006-05-10)',
#   'Prod.code': '122',
#   'US viewers(millions)': '12.67'},
#  {'No. inseason': '5',
#   'Title': '"Broken Mirror"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Judith McCreary',
#   'Original air date': 'October\xa019,\xa02005\xa0(2005-10-19)',
#   'Prod.code': '105',
#   'US viewers(millions)': '12.79'},
#  {'No. inseason': '9',
#   'Title': '"Derailed"',
#   'Directed by': 'Félix Alcalá',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'November\xa023,\xa02005\xa0(2005-11-23)',
#   'Prod.code': '109',
#   'US viewers(millions)': '12.83'},
#  {'No. inseason': '17',
#   'Title': '"A Real Rain"',
#   'Directed by': 'Gloria Muzio',
#   'Written by': 'Chris Mundy',
#   'Original air date': 'March\xa022,\xa02006\xa0(2006-03-22)',
#   'Prod.code': '117',
#   'US viewers(millions)': '13.03'},
#  {'No. inseason': '20',
#   'Title': '"Charm and Harm"',
#   'Directed by': 'Félix Alcalá',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'April\xa019,\xa02006\xa0(2006-04-19)',
#   'Prod.code': '120',
#   'US viewers(millions)': '13.53'},
#  {'No. inseason': '4',
#   'Title': '"Plain Sight"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'October\xa012,\xa02005\xa0(2005-10-12)',
#   'Prod.code': '104',
#   'US viewers(millions)': '13.76'},
#  {'No. inseason': '14',
#   'Title': '"Riding the Lightning"',
#   'Directed by': 'Chris Long',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'January\xa025,\xa02006\xa0(2006-01-25)',
#   'Prod.code': '114',
#   'US viewers(millions)': '14.10'},
#  {'No. inseason': '8',
#   'Title': '"Natural Born Killer"',
#   'Directed by': 'Peter Ellis',
#   'Written by': 'Debra J. Fisher & Erica Messer',
#   'Original air date': 'November\xa016,\xa02005\xa0(2005-11-16)',
#   'Prod.code': '108',
#   'US viewers(millions)': '14.36'},
#  {'No. inseason': '13',
#   'Title': '"Poison"',
#   'Directed by': 'Thomas J. Wright',
#   'Written by': 'Aaron Zelman',
#   'Original air date': 'January\xa018,\xa02006\xa0(2006-01-18)',
#   'Prod.code': '113',
#   'US viewers(millions)': '14.65'},
#  {'No. inseason': '7',
#   'Title': '"The Fox"',
#   'Directed by': 'Guy Norman Bee',
#   'Written by': 'Simon Mirren',
#   'Original air date': 'November\xa09,\xa02005\xa0(2005-11-09)',
#   'Prod.code': '107',
#   'US viewers(millions)': '15.09'},
#  {'No. inseason': '11',
#   'Title': '"Blood Hungry"',
#   'Directed by': 'Charles Haid',
#   'Written by': 'Ed Napier',
#   'Original air date': 'December\xa014,\xa02005\xa0(2005-12-14)',
#   'Prod.code': '111',
#   'US viewers(millions)': '15.23'},
#  {'No. inseason': '16',
#   'Title': '"The Tribe"',
#   'Directed by': 'Matt Earl Beesley',
#   'Written by': 'Andrew Wilder',
#   'Original air date': 'March\xa08,\xa02006\xa0(2006-03-08)',
#   'Prod.code': '116',
#   'US viewers(millions)': '15.27'},
#  {'No. inseason': '10',
#   'Title': '"The Popular Kids"',
#   'Directed by': 'Andy Wolk',
#   'Written by': 'Edward Allen Bernero',
#   'Original air date': 'November\xa030,\xa02005\xa0(2005-11-30)',
#   'Prod.code': '110',
#   'US viewers(millions)': '15.56'},
#  {'No. inseason': '12',
#   'Title': '"What Fresh Hell"',
#   'Directed by': 'Adam Davidson',
#   'Written by': 'Judith McCreary',
#   'Original air date': 'January\xa011,\xa02006\xa0(2006-01-11)',
#   'Prod.code': '112',
#   'US viewers(millions)': '15.92'},
#  {'No. inseason': '6',
#   'Title': '"L.D.S.K."',
#   'Directed by': 'Ernest Dickerson',
#   'Written by': 'Andrew Wilder',
#   'Original air date': 'November\xa02,\xa02005\xa0(2005-11-02)',
#   'Prod.code': '106',
#   'US viewers(millions)': '16.22'},
#  {'No. inseason': 1,
#   'Title': '"Extreme Aggressor"',
#   'Directed by': 'Richard Shepard',
#   'Written by': 'Jeff Davis',
#   'Original air date': 'September\xa022,\xa02005\xa0(2005-09-22)',
#   'Prod.code': 101,
#   'US viewers(millions)': '19.57'}]

# %% [markdown]
# #### Cleaning

# %% [markdown]
# We can loop over the list to make changes to our data. Here we use the `.isnumeric()` [string method](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str) to determine whether a string can be converted to an `int` or `float`. We'll also use the `.replace()` method to remove periods and commas from strings as needed.

# %%
print(ridata[0])

for row in ridata:
    if row['Year established'].isnumeric():
        row['Year established'] = int(row['Year established'])
    if row['Land area(2010) sq mi'].replace('.', '').isnumeric(): 
        row['Land area(2010) sq mi'] = float(row['Land area(2010) sq mi'])
    if row['Population(2010)'].replace('.', '').replace(',','').isnumeric():
        row['Population(2010)'] = int(row['Population(2010)'].replace(',',''))
# Out:
# {'Name': 'Barrington', 'Type': 'Town', 'County': 'Bristol', 'Year established': 1653, 'Year incorporated': '1770', 'Form of government': 'Council–manager', 'Population(2010)': 16310, 'Population(2000)': '16,819', 'Change': '−3.0%', 'Land area(2010) sq mi': 8.22, 'Land area(2010) km2': '21.3', 'Population density': '1,984.2/sq\xa0mi (766.1/km2)'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-34cdc45b6679> in <module>
#       2
#       3 for row in ridata:
# ----> 4     if row['Year established'].isnumeric():
#       5         row['Year established'] = int(row['Year established'])
#       6     if row['Land area(2010) sq mi'].replace('.', '').isnumeric():
#
# AttributeError: 'int' object has no attribute 'isnumeric'

# %%
ridata[0]
# Out:
# {'Name': 'Barrington',
#  'Type': 'Town',
#  'County': 'Bristol',
#  'Year established': 1653,
#  'Year incorporated': '1770',
#  'Form of government': 'Council–manager',
#  'Population(2010)': 16310,
#  'Population(2000)': '16,819',
#  'Change': '−3.0%',
#  'Land area(2010) sq mi': 8.22,
#  'Land area(2010) km2': '21.3',
#  'Population density': '1,984.2/sq\xa0mi (766.1/km2)'}

# %% [markdown]
# We can use the `.split()` string method to extract specific parts of a string when we know the string has some regular formatting. For example:

# %%
pd = ridata[0]['Population density']
print(ridata[0]['Name']+"'s population density:", pd)
#Population density per square mile:
print("Per square mile", pd.split('/')[0])

#per square km:
print("Per square kilometer:", pd.split('(')[1].split('/')[0])
# Out:
# Barrington's population density: 1,984.2/sq mi (766.1/km2)
# Per square mile 1,984.2
# Per square kilometer: 766.1

# %% [markdown]
# ##### Practice
# Find a field in your data that should be numeric and convert it to integers or floating-point numbers.

# %%
print(season1data[0])

for row in season1data:
    if type(row['US viewers(millions)']) == str and row['US viewers(millions)'].replace('.','').isnumeric():
        row['US viewers(millions)'] = float(row['US viewers(millions)'])
    
        
season1data[1]
# Out:
# {'No. inseason': 1, 'Title': '"Extreme Aggressor"', 'Directed by': 'Richard Shepard', 'Written by': 'Jeff Davis', 'Original air date': 'September\xa022,\xa02005\xa0(2005-09-22)', 'Prod.code': 101, 'US viewers(millions)': '19.57'}
# {'No. inseason': 2,
#  'Title': '"Compulsion"',
#  'Directed by': 'Charles Haid',
#  'Written by': 'Jeff Davis',
#  'Original air date': 'September\xa028,\xa02005\xa0(2005-09-28)',
#  'Prod.code': 102,
#  'US viewers(millions)': 10.57}

# %% [markdown]
# #### Derived fields
#
# Sometimes, the numbers we want to analyze are not provided in the data we have, but can be calculated from that data. We'll want to add new fields to the data with our calculated figures.
#
# Earlier, I showed how we could extract population density from the numbers above. But we can also calculate it from the population and area numbers we've already converted to numeric variables:

# %%
pop  = ridata[0]['Population(2010)']
area = ridata[0]['Land area(2010) sq mi']
print(ridata[0]['Name']+"'s population density:", pop/area, "/square mile")
# Out:
# Barrington's population density: 1984.184914841849 /square mile

# %% [markdown]
# We can add this figure to every row of our data:

# %%
for row in ridata:
    row['population_density'] = row['Population(2010)'] / row['Land area(2010) sq mi']

ridata
# Out:
# [{'Name': 'Barrington',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': 1653,
#   'Year incorporated': '1770',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 16310,
#   'Population(2000)': '16,819',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': 8.22,
#   'Land area(2010) km2': '21.3',
#   'Population density': '1,984.2/sq\xa0mi (766.1/km2)',
#   'population_density': 1984.184914841849},
#  {'Name': 'Bristol',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': 1680,
#   'Year incorporated': '1746',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 22954,
#   'Population(2000)': '22,469',
#   'Change': '+2.2%',
#   'Land area(2010) sq mi': 9.82,
#   'Land area(2010) km2': '25.4',
#   'Population density': '2,337.5/sq\xa0mi (902.5/km2)',
#   'population_density': 2337.4745417515273},
#  {'Name': 'Burrillville',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1730,
#   'Year incorporated': '1806',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 15955,
#   'Population(2000)': '15,796',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': 55.03,
#   'Land area(2010) km2': '142.5',
#   'Population density': '289.9/sq\xa0mi (111.9/km2)',
#   'population_density': 289.93276394693805},
#  {'Name': 'Central Falls',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1730,
#   'Year incorporated': '1895',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 19376,
#   'Population(2000)': '18,928',
#   'Change': '+2.4%',
#   'Land area(2010) sq mi': 1.2,
#   'Land area(2010) km2': '3.1',
#   'Population density': '16,146.7/sq\xa0mi (6,234.3/km2)',
#   'population_density': 16146.666666666668},
#  {'Name': 'Charlestown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1669,
#   'Year incorporated': '1738',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 7827,
#   'Population(2000)': '7,859',
#   'Change': '−0.4%',
#   'Land area(2010) sq mi': 36.45,
#   'Land area(2010) km2': '94.4',
#   'Population density': '214.7/sq\xa0mi (82.9/km2)',
#   'population_density': 214.73251028806584},
#  {'Name': 'Coventry',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': 1639,
#   'Year incorporated': '1743[b]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 35014,
#   'Population(2000)': '33,668',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': 59.05,
#   'Land area(2010) km2': '152.9',
#   'Population density': '593.0/sq\xa0mi (228.9/km2)',
#   'population_density': 592.9551227773075},
#  {'Name': 'Cranston',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1754,
#   'Year incorporated': '1910',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 80387,
#   'Population(2000)': '79,269',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': 28.34,
#   'Land area(2010) km2': '73.4',
#   'Population density': '2,836.5/sq\xa0mi (1,095.2/km2)',
#   'population_density': 2836.5208186309105},
#  {'Name': 'Cumberland',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1746,
#   'Year incorporated': '1746',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 33506,
#   'Population(2000)': '31,840',
#   'Change': '+5.2%',
#   'Land area(2010) sq mi': 26.45,
#   'Land area(2010) km2': '68.5',
#   'Population density': '1,266.8/sq\xa0mi (489.1/km2)',
#   'population_density': 1266.7674858223063},
#  {'Name': 'East Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': 1677,
#   'Year incorporated': '1677[c]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 13146,
#   'Population(2000)': '12,948',
#   'Change': '+1.5%',
#   'Land area(2010) sq mi': 16.39,
#   'Land area(2010) km2': '42.4',
#   'Population density': '802.1/sq\xa0mi (309.7/km2)',
#   'population_density': 802.0744356314826},
#  {'Name': 'East Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1812,
#   'Year incorporated': '1958',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 47037,
#   'Population(2000)': '48,688',
#   'Change': '−3.4%',
#   'Land area(2010) sq mi': 13.24,
#   'Land area(2010) km2': '34.3',
#   'Population density': '3,552.6/sq\xa0mi (1,371.7/km2)',
#   'population_density': 3552.643504531722},
#  {'Name': 'Exeter',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1641,
#   'Year incorporated': '1641[d]',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 6425,
#   'Population(2000)': '6,045',
#   'Change': '+6.3%',
#   'Land area(2010) sq mi': 57.47,
#   'Land area(2010) km2': '148.8',
#   'Population density': '111.8/sq\xa0mi (43.2/km2)',
#   'population_density': 111.79745954410997},
#  {'Name': 'Foster',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1781',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 4606,
#   'Population(2000)': '4,274',
#   'Change': '+7.8%',
#   'Land area(2010) sq mi': 50.8,
#   'Land area(2010) km2': '131.6',
#   'Population density': '90.7/sq\xa0mi (35.0/km2)',
#   'population_density': 90.66929133858268},
#  {'Name': 'Glocester',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1639,
#   'Year incorporated': '1730–1731',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 9746,
#   'Population(2000)': '9,948',
#   'Change': '−2.0%',
#   'Land area(2010) sq mi': 54.18,
#   'Land area(2010) km2': '140.3',
#   'Population density': '179.9/sq\xa0mi (69.5/km2)',
#   'population_density': 179.88187523071244},
#  {'Name': 'Hopkinton',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1639,
#   'Year incorporated': '1757',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 8188,
#   'Population(2000)': '7,836',
#   'Change': '+4.5%',
#   'Land area(2010) sq mi': 42.95,
#   'Land area(2010) km2': '111.2',
#   'Population density': '190.6/sq\xa0mi (73.6/km2)',
#   'population_density': 190.64027939464492},
#  {'Name': 'Jamestown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': 1639,
#   'Year incorporated': '1678',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 5405,
#   'Population(2000)': '5,622',
#   'Change': '−3.9%',
#   'Land area(2010) sq mi': 9.45,
#   'Land area(2010) km2': '24.5',
#   'Population density': '572.0/sq\xa0mi (220.8/km2)',
#   'population_density': 571.957671957672},
#  {'Name': 'Johnston',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1759',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 28769,
#   'Population(2000)': '28,195',
#   'Change': '+2.0%',
#   'Land area(2010) sq mi': 23.43,
#   'Land area(2010) km2': '60.7',
#   'Population density': '1,227.9/sq\xa0mi (474.1/km2)',
#   'population_density': 1227.870251813914},
#  {'Name': 'Lincoln',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1650,
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 21105,
#   'Population(2000)': '20,898',
#   'Change': '+1.0%',
#   'Land area(2010) sq mi': 18.12,
#   'Land area(2010) km2': '46.9',
#   'Population density': '1,164.7/sq\xa0mi (449.7/km2)',
#   'population_density': 1164.7350993377484},
#  {'Name': 'Little Compton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': 1682,
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 3492,
#   'Population(2000)': '3,593',
#   'Change': '−2.8%',
#   'Land area(2010) sq mi': 20.52,
#   'Land area(2010) km2': '53.1',
#   'Population density': '170.2/sq\xa0mi (65.7/km2)',
#   'population_density': 170.17543859649123},
#  {'Name': 'Middletown',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': 1639,
#   'Year incorporated': '1743',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 16150,
#   'Population(2000)': '17,334',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': 12.72,
#   'Land area(2010) km2': '32.9',
#   'Population density': '1,269.7/sq\xa0mi (490.2/km2)',
#   'population_density': 1269.6540880503144},
#  {'Name': 'Narragansett',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1888,
#   'Year incorporated': '1901',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 15868,
#   'Population(2000)': '16,361',
#   'Change': '−3.0%',
#   'Land area(2010) sq mi': 13.89,
#   'Land area(2010) km2': '36.0',
#   'Population density': '1,142.4/sq\xa0mi (441.1/km2)',
#   'population_density': 1142.4046076313894},
#  {'Name': 'Newport',
#   'Type': 'City',
#   'County': 'Newport',
#   'Year established': 1639,
#   'Year incorporated': '1784[e]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 24672,
#   'Population(2000)': '26,475',
#   'Change': '−6.8%',
#   'Land area(2010) sq mi': 7.67,
#   'Land area(2010) km2': '19.9',
#   'Population density': '3,216.7/sq\xa0mi (1,242.0/km2)',
#   'population_density': 3216.6883963494133},
#  {'Name': 'New Shoreham',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1664,
#   'Year incorporated': '1672',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 1051,
#   'Population(2000)': '1,010',
#   'Change': '+4.1%',
#   'Land area(2010) sq mi': 9.08,
#   'Land area(2010) km2': '23.5',
#   'Population density': '115.7/sq\xa0mi (44.7/km2)',
#   'population_density': 115.7488986784141},
#  {'Name': 'North Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1641,
#   'Year incorporated': '1674',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 26486,
#   'Population(2000)': '26,326',
#   'Change': '+0.6%',
#   'Land area(2010) sq mi': 43.14,
#   'Land area(2010) km2': '111.7',
#   'Population density': '614.0/sq\xa0mi (237.0/km2)',
#   'population_density': 613.9545665275846},
#  {'Name': 'North Providence',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1765',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 32078,
#   'Population(2000)': '32,411',
#   'Change': '−1.0%',
#   'Land area(2010) sq mi': 5.62,
#   'Land area(2010) km2': '14.6',
#   'Population density': '5,707.8/sq\xa0mi (2,203.8/km2)',
#   'population_density': 5707.8291814946615},
#  {'Name': 'North Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1730,
#   'Year incorporated': '1871',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 11967,
#   'Population(2000)': '10,618',
#   'Change': '+12.7%',
#   'Land area(2010) sq mi': 23.8,
#   'Land area(2010) km2': '61.6',
#   'Population density': '502.8/sq\xa0mi (194.1/km2)',
#   'population_density': 502.81512605042013},
#  {'Name': 'Pawtucket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1671,
#   'Year incorporated': '1954',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 71148,
#   'Population(2000)': '72,958',
#   'Change': '−2.5%',
#   'Land area(2010) sq mi': 8.68,
#   'Land area(2010) km2': '22.5',
#   'Population density': '8,196.8/sq\xa0mi (3,164.8/km2)',
#   'population_density': 8196.774193548388},
#  {'Name': 'Portsmouth',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': 1638,
#   'Year incorporated': '1640[f]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 17389,
#   'Population(2000)': '17,149',
#   'Change': '+1.4%',
#   'Land area(2010) sq mi': 22.98,
#   'Land area(2010) km2': '59.5',
#   'Population density': '756.7/sq\xa0mi (292.2/km2)',
#   'population_density': 756.7014795474325},
#  {'Name': 'Providence',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1832',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 178042,
#   'Population(2000)': '173,618',
#   'Change': '+2.5%',
#   'Land area(2010) sq mi': 18.4,
#   'Land area(2010) km2': '47.7',
#   'Population density': '9,676.2/sq\xa0mi (3,736.0/km2)',
#   'population_density': 9676.195652173914},
#  {'Name': 'Richmond',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1669,
#   'Year incorporated': '1747',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 7708,
#   'Population(2000)': '7,222',
#   'Change': '+6.7%',
#   'Land area(2010) sq mi': 40.29,
#   'Land area(2010) km2': '104.4',
#   'Population density': '191.3/sq\xa0mi (73.9/km2)',
#   'population_density': 191.31298088855795},
#  {'Name': 'Scituate',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1730',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 10329,
#   'Population(2000)': '10,324',
#   'Change': '0.0%',
#   'Land area(2010) sq mi': 48.16,
#   'Land area(2010) km2': '124.7',
#   'Population density': '214.5/sq\xa0mi (82.8/km2)',
#   'population_density': 214.47259136212625},
#  {'Name': 'Smithfield',
#   'Type': 'Town',
#   'County': 'Providence',
#   'Year established': 1636,
#   'Year incorporated': '1730',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 21430,
#   'Population(2000)': '20,613',
#   'Change': '+4.0%',
#   'Land area(2010) sq mi': 26.31,
#   'Land area(2010) km2': '68.1',
#   'Population density': '814.5/sq\xa0mi (314.5/km2)',
#   'population_density': 814.5191942227291},
#  {'Name': 'South Kingstown',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1657,
#   'Year incorporated': '1723[g]',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 30639,
#   'Population(2000)': '27,921',
#   'Change': '+9.7%',
#   'Land area(2010) sq mi': 56.45,
#   'Land area(2010) km2': '146.2',
#   'Population density': '542.8/sq\xa0mi (209.6/km2)',
#   'population_density': 542.7635075287865},
#  {'Name': 'Tiverton',
#   'Type': 'Town',
#   'County': 'Newport',
#   'Year established': 1694,
#   'Year incorporated': '1746',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 15780,
#   'Population(2000)': '15,260',
#   'Change': '+3.4%',
#   'Land area(2010) sq mi': 29.05,
#   'Land area(2010) km2': '75.2',
#   'Population density': '543.2/sq\xa0mi (209.7/km2)',
#   'population_density': 543.2013769363167},
#  {'Name': 'Warren',
#   'Type': 'Town',
#   'County': 'Bristol',
#   'Year established': 1620,
#   'Year incorporated': '1747',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 10611,
#   'Population(2000)': '11,360',
#   'Change': '−6.6%',
#   'Land area(2010) sq mi': 6.12,
#   'Land area(2010) km2': '15.9',
#   'Population density': '1,733.8/sq\xa0mi (669.4/km2)',
#   'population_density': 1733.8235294117646},
#  {'Name': 'Warwick',
#   'Type': 'City',
#   'County': 'Kent',
#   'Year established': 1642,
#   'Year incorporated': '1931',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 82672,
#   'Population(2000)': '85,808',
#   'Change': '−3.7%',
#   'Land area(2010) sq mi': 35.04,
#   'Land area(2010) km2': '90.8',
#   'Population density': '2,359.4/sq\xa0mi (911.0/km2)',
#   'population_density': 2359.3607305936075},
#  {'Name': 'Westerly',
#   'Type': 'Town',
#   'County': 'Washington',
#   'Year established': 1661,
#   'Year incorporated': '1669',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 22787,
#   'Population(2000)': '22,966',
#   'Change': '−0.8%',
#   'Land area(2010) sq mi': 29.52,
#   'Land area(2010) km2': '76.5',
#   'Population density': '771.9/sq\xa0mi (298.0/km2)',
#   'population_density': 771.9173441734417},
#  {'Name': 'West Greenwich',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': 1639,
#   'Year incorporated': '1741',
#   'Form of government': 'Town meeting',
#   'Population(2010)': 6135,
#   'Population(2000)': '5,085',
#   'Change': '+20.6%',
#   'Land area(2010) sq mi': 50.26,
#   'Land area(2010) km2': '130.2',
#   'Population density': '122.1/sq\xa0mi (47.1/km2)',
#   'population_density': 122.06526064464784},
#  {'Name': 'West Warwick',
#   'Type': 'Town',
#   'County': 'Kent',
#   'Year established': 1648,
#   'Year incorporated': '1913',
#   'Form of government': 'Council–manager',
#   'Population(2010)': 29191,
#   'Population(2000)': '29,581',
#   'Change': '−1.3%',
#   'Land area(2010) sq mi': 7.79,
#   'Land area(2010) km2': '20.2',
#   'Population density': '3,747.2/sq\xa0mi (1,446.8/km2)',
#   'population_density': 3747.240051347882},
#  {'Name': 'Woonsocket',
#   'Type': 'City',
#   'County': 'Providence',
#   'Year established': 1867,
#   'Year incorporated': '1888',
#   'Form of government': 'Mayor–council',
#   'Population(2010)': 41186,
#   'Population(2000)': '43,224',
#   'Change': '−4.7%',
#   'Land area(2010) sq mi': 7.74,
#   'Land area(2010) km2': '20.0',
#   'Population density': '5,321.2/sq\xa0mi (2,054.5/km2)',
#   'population_density': 5321.188630490956}]

# %% [markdown]
# #### Summary Statistics
#
# We've already discusses reading "columns" of data; with the functions in the [`statistics`](https://docs.python.org/3/library/statistics.html) module and the `min()` and `max()` functions, we can summarize those columns.

# %%
import statistics

print(statistics.mean([x['Land area(2010) sq mi'] for x in ridata]))
print(min([x['Land area(2010) sq mi'] for x in ridata]), max([x['Land area(2010) sq mi'] for x in ridata]))
# Out:
# 26.508205128205127
# 1.2 59.05

# %% [markdown]
# ##### Practice

# %% [markdown]
# Calculate the mean and range (maximum and minimum values) for a numeric field in one of the loaded datasets.

# %%
print(statistics.mean([x['US viewers(millions)'] for x in season1data]))
print(min([x['US viewers(millions)'] for x in season1data]), max([x['US viewers(millions)'] for x in season1data]))
# Out:
# 13.878181818181819
# 10.57 19.57
